# %%
# !pip install streamlit
# !pip install db-sqlite3
# !pip install pymongo
# !pip install plotly-express
# !pip install seaborn
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: streamlit in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (1.26.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (5.1.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<10,>=7.1.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (4.24.2)
# Requirement already satisfied: pyarrow>=6.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (2.29.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (13.5.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (4.6.3)
# Requirement already satisfied: tzlocal<5,>=1.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.34)
# Requirement already satisfied: pydeck<1,>=0.8 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from streamlit) (6.2)
# Requirement already satisfied: jinja2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.18->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.18->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.18->streamlit) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: tzdata in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit) (2023.3)
# Requirement already satisfied: db-sqlite3 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (0.0.1)
# Requirement already satisfied: db in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from db-sqlite3) (0.1.1)
# Requirement already satisfied: antiorm in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from db->db-sqlite3) (1.2.1)
# Requirement already satisfied: pymongo in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (4.4.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pymongo) (2.4.2)
# Requirement already satisfied: plotly-express in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (1.5.3)
# Requirement already satisfied: plotly>=4.1.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (5.9.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (0.13.5)
# Requirement already satisfied: scipy>=0.18 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (1.10.1)
# Requirement already satisfied: patsy>=0.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (0.5.3)
# Requirement already satisfied: numpy>=1.11 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly-express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pandas>=0.20.0->plotly-express) (2022.7)
# Requirement already satisfied: six in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from plotly>=4.1.0->plotly-express) (8.2.2)
# Requirement already satisfied: packaging>=21.3 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.9.0->plotly-express) (23.0)
# Requirement already satisfied: seaborn in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: google-api-python-client in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (2.101.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.23.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.12.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.24.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.29.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/advikiashwin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.5.7)

# %%
#Pandas,Numpy
import pandas as pd
import numpy as np
#MongoDB
import pymongo
from pymongo import MongoClient
#SQLite
import sqlite3
#File handling libraries
import json
#Dash board libraries
import streamlit as st
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
#Youtube API libraries
import googleapiclient.discovery
from googleapiclient.discovery import build

# %%
# Comfiguring Streamlit GUI
st.set_page_config(layout='wide')
#Title
st.title(':black[Youtube Data Harvesting]')

# %%
# Data collection zone
st.header(':violet[Data collection zone]')
st.write ('(Note:- This zone **collect data** by using channel id and **stored it in the :green[MongoDB] database**.)')
channel_id = st.text_input('**Enter 11 digit channel_id**')
st.write('''Get data and stored it in the MongoDB database to click below **:blue['Get data and stored']**.''')
key = st.button('**Get data and stored**')

# %%
# Create a YouTube API client
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey='AIzaSyA8QZDyoVymyfkY3Vy8JYTsezusviaG7uA')

# %%
# Defining function to get channel data
def get_channel_data(youtube,channel_id):
# Fetch channel details
    channel_response = youtube.channels().list(
    id=channel_id,
    part='snippet,statistics,contentDetails')
    channel_detls = channel_response.execute()
# Extract relevant information
    c_data = dict ( Channel_name = channel_detls['items'][0]['snippet']['title'],
                    Channel_ID = channel_detls['items'][0]['id'],
                    Subscribers = channel_detls['items'][0]['statistics']['subscriberCount'],
                    Views = channel_detls['items'][0]['statistics']['viewCount'],
                    Description = channel_detls['items'][0]['snippet']['description'],
                    Total_Videos = channel_detls['items'][0]['statistics']['videoCount'],
                    Playlist_id = channel_detls['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
                  )
    return c_data

# %%
# Defining function to get Video_ID Details from Playlist:
def get_videoID_data(youtube,playlist_id):
# Fetch playlist ID
    vid_details = []
    request = youtube.playlistItems().list(
    part='contentDetails',
    playlistId= playlist_id,
    maxResults=50)
    response = request.execute()
#Extract relevant information
    for item in response['items']:
     vid_details.append (item['contentDetails']['videoId'])
    return vid_details

# %%
# Defining function to get video details of each video in the playlist:
def get_videodetails(youtube,video_IDs):
# Fetch video details
  data=[]
  for i in video_IDs:
    request = youtube.videos().list(
    part='snippet,statistics,contentDetails',
    id= i )
    response = request.execute()
# Extract relevant information
    data.append ({"Video_ID": i,
                "Channel_Id": response['items'][0]['snippet']['channelId'], 
                "Video_Name": response['items'][0]['snippet']['title'],
                "Video_Description":response['items'][0]['snippet']['description'],
                "Video_Statistics": response['items'][0]['statistics']['commentCount'],
                "Comment_Count": response['items'][0]['statistics'].get('commentCount', 0),
                "View_Count": response['items'][0]['statistics'].get('viewCount', 0),
                "Like_Count": response['items'][0]['statistics'].get('likeCount', 0),
                "Favorite_Count": response['items'][0]['statistics'].get('favoriteCount', 0),
                "Published_At": response['items'][0]['snippet']['publishedAt'],
                "Duration": response['items'][0]['contentDetails']['duration'],
                "Thumbnail": response['items'][0]['snippet']['thumbnails']['default']['url'],
                "Caption_Status": response['items'][0]['contentDetails'].get('caption')
                })
  return data

# %%
# Defining function to get Commands of each videos
def get_comments_details(youtube,videoID_data):
# Fetch comment details
    v_c_data=[]
    for i in videoID_data:
        try:
            comments_response = youtube.commentThreads().list(
            part='snippet',
            maxResults=2,  # only 2 comments
            videoId=i)
            response=comments_response.execute()
            comments = response['items']
# Extract relevant information
            for comment in comments:
                comment_information = {
                                  "Video_iD": i,
                                  "Comment_Id": comment['snippet']['topLevelComment']['id'],
                                  "Comment_Text": comment['snippet']['topLevelComment']['snippet']['textDisplay'],
                                  "Comment_Author": comment['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                  "Comment_PublishedAt": comment['snippet']['topLevelComment']['snippet']['publishedAt']
                                  }
            v_c_data.append(comment_information)
        except:
          pass
    return v_c_data

# %%
# Defining main function
def main(channel_id):
  c = get_channel_data(youtube,channel_id)
  p = get_videoID_data(youtube,c['Playlist_id'])
  v = get_videodetails(youtube,p)
  cm = get_comments_details(youtube,p)
# Assinging datas into a variable
  data = {'channel details':c,
          'playlist details':p,
          'video details':v,
          'comment details':cm}
  return data

# %%
channel_id = 'UCDnq05Q89oYq-Tz5boL73Tw'
d = main(channel_id)

# %%
d.keys()
# Out:
# dict_keys(['channel details', 'playlist details', 'video details', 'comment details'])

# %%
d
# Out:
# {'channel details': {'Channel_name': 'Curly Tales ',
#   'Channel_ID': 'UCDnq05Q89oYq-Tz5boL73Tw',
#   'Subscribers': '2570000',
#   'Views': '998914452',
#   'Description': "Welcome to Curly Tales - India's No. 1 food & travel channel, founded by Kamiya Jani. We'll take you on a journey through some of the most offbeat locations & the quirkiest, craziest food discoveries. So hop on, and enjoy the ride as we bring to you 7 exclusive shows, every day of the week:\n\nSunday Brunch with Kamiya Jani: A fun tete a tete with India's biggest celebrities \nCT Discovery: Unique food & places across India, you KNOW you can't miss out on\nTere Gully Mein: A walk down memory lane with popular influencers, as they take us through their favourite gullies & food memories\nThe Solo Female Traveller: Neha Nambiar's solo journey through India's wilderness. Sometimes luxury, but mostly budget trips\nCT Exclusives: The best deals on food & travel, that you won't get anywhere else!\nI Love My India: Our country has so much to offer, & we bring you Bharat's beauty in all its glory\nWanderluxe: Have you ever wondered what outrageous, OTT luxury lives like? Well, we're here to show you\n",
#   'Total_Videos': '3424',
#   'Playlist_id': 'UUDnq05Q89oYq-Tz5boL73Tw'},
#  'playlist details': ['FRR55XRcuHY',
#   'RvI_ObX0rLQ',
#   'wVol-v3WglQ',
#   'gvDClSHLhCk',
#   '8KikL1A8tYI',
#   'GBS2R4Iiado',
#   '-hRYBY1F2Jc',
#   'V5N0inwvFoo',
#   'oKN0rdp3Ak0',
#   'OQfK8sa6FQw',
#   'vfeFeCq14n8',
#   'IaJR6hZg76Q',
#   '0i2A0gsuKKA',
#   'Cx2T0zYEJw4',
#   '9gZXrWybYfA',
#   '5DQeQi8LXDc',
#   'fF5eo4xK3_g',
#   'aNoiYgOyyJU',
#   'Q0W6B7c77E8',
#   '5eLMLbEGH4Q',
#   'f6-hmi_JbeA',
#   '8ccR_FTvxCY',
#   'SWJJgFBPxPQ',
#   'bGwJVF8VcTM',
#   'v8NME2PL9gg',
#   'tA2kp-2rIos',
#   'YrZc9B2rdwg',
#   'f2bDtLow090',
#   '9jICSNsAB5k',
#   'wPVu5lK-8rY',
#   'Itv10IA7QFY',
#   'AudQBklkmzk',
#   'e6NTQQ6U5rc',
#   'mWiYig-z62E',
#   '0D_NBlTfKDU',
#   'S1YctSbkw7c',
#   'msbIRfwYya4',
#   'rBxk49emoPk',
#   'aZRPJxEQDgY',
#   'Smsk6WmDpTM',
#   'NdmUekinsa0',
#   'RNvaB6DzDxs',
#   'JT2WODYQMu8',
#   'HL1_hHUxOmg',
#   'vpu8TTlq_hk',
#   'pBJ8DGQB1ag',
#   'qzpSdJgU1dg',
#   'rkCHCCYtHfA',
#   'ddGQEnu62gc',
#   'Zq3A6wi7IK4'],
#  'video details': [{'Video_ID': 'FRR55XRcuHY',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Does this kachori come in a mask? Guess We’ll Never Know | Curly Tales #shorts',
#    'Video_Description': 'Does this kachori come in a mask? Guess we’ll never know!!😂🤪\n\n#rajkachori #shilpashetty #kushakapila #curlytales #funnymovement #ytshorts #bollywood #viral #travel \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/\nCurly Tales App ►  https://curlytale.page.link/DwNd',
#    'Video_Statistics': '5',
#    'Comment_Count': '5',
#    'View_Count': '12233',
#    'Like_Count': '812',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-03T15:45:00Z',
#    'Duration': 'PT53S',
#    'Thumbnail': 'https://i.ytimg.com/vi/FRR55XRcuHY/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'RvI_ObX0rLQ',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'From Selling Their Home To Owning A ₹600 Crore Company | Stories From Bharat Ep 17 | Curly Tales',
#    'Video_Description': 'In this episode  Of Stories From Bharat, we dive into the incredible journey of Rahul and Priyanka, a couple who moved from Boston to India with a dream of building their own eco-friendly home essentials startup, EcoSoul Home. From sleeping on the floor in a cramped apartment to selling their home to fund the business, their story is a testament to resilience and determination. Discover how they turned their vision into reality, replacing plastic with sustainable products and making a significant impact on the environment. Get inspired by their journey from zero to a 600 Cr revenue run rate, all while staying true to their mission of a cleaner, greener planet.\n\nCurly Tales Is hosting a givea
Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Roller Coaster Kulfi In Delhi\n\n📍 The Kulfi Factory Kamla Nagar\n\nCost: ₹80\n\nTiming - 12.30 pm to 11.30 pm\n\nThis Roller Coaster Kulfi is made with many fruits like papaya, oranges, apple and many fruit syrups.\n\nTag A Kulfi Lover\n\nFollow @curlytalesdigital  For More\n#curlytales #foodandtravel #ctdiscovery #ytshorts #foodblogger #foodie #kulfi',
#    'Video_Statistics': '6',
#    'Comment_Count': '6',
#    'View_Count': '17378',
#    'Like_Count': '699',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-02T13:00:22Z',
#    'Duration': 'PT33S',
#    'Thumbnail': 'https://i.ytimg.com/vi/V5N0inwvFoo/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'oKN0rdp3Ak0',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Afgani Burger In Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Afghani Burger in Delhi\n\n📍Block E, Lajpat Nagar\n\nCost - ₹50\nTiming - 10am to 11pm\n\nIt is stuffed with veggies, boiled egg and loads of french fries\n\nTag A Afghani Food Lover !\n\n\n#delhi #afghani #burger #curlytales #streetfood #delhi #foodandtravel #travel',
#    'Video_Statistics': '4',
#    'Comment_Count': '4',
#    'View_Count': '18513',
#    'Like_Count': '653',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-01T15:00:41Z',
#    'Duration': 'PT31S',
#    'Thumbnail': 'https://i.ytimg.com/vi/oKN0rdp3Ak0/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'OQfK8sa6FQw',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Sadhguru Gives Parental Advice For Kids Of This Era | Curly Tales #shorts',
#    'Video_Description': 'Sadhguru Gives Parental Advice For Kids Of This Era.\n\n\n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/',
#    'Video_Statistics': '4',
#    'Comment_Count': '4',
#    'View_Count': '13792',
#    'Like_Count': '756',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-01T15:00:29Z',
#    'Duration': 'PT55S',
#    'Thumbnail': 'https://i.ytimg.com/vi/OQfK8sa6FQw/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'vfeFeCq14n8',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Here’s How You Can Make New Friends in Bengaluru | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Here’s How You Can Make New Friends in Bengaluru\n\nIf you are tired of swiping online for dates or just to meet new people, then this social mixer is all you need! @small.world curates events to create meaningful relations.\n\nVisit @small.world ‘s link in bio to book your tickets for your favourite event, be it Bachata Dance, Blindfolded Talks, Speed dating, Chai Date, and many more!\n\n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/\nCurly Tales App ►  https://curlytale.page.link/DwNd',
#    'Video_Statistics': '1',
#    'Comment_Count': '1',
#    'View_Count': '15367',
#    'Like_Count': '460',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-01T11:45:03Z',
#    'Duration': 'PT1M',
#    'Thumbnail': 'https://i.ytimg.com/vi/vfeFeCq14n8/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'IaJR6hZg76Q',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Biggest Bahubali Roll In Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Biggest Bahubali Roll In Delhi\n\n📍Wong’s Kitchen, Rohini\n\nCost- ₹999\n\nTime - 1pm - 12am\n\nStuffed With Paneer Tikka And Noodles\n\nTag a Bahubali lover !\nFollow @curlytalesdigital  for more\n\n#curlytales #ctdiscovery #foodandtravel #ytshorts #foodie #bahubaliroll #delhifoodie \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/',
#    'Video_Statistics': '22',
#    'Comment_Count': '22',
#    'View_Count': '27023',
#    'Like_Count': '969',
#    'Favorite_Count': '0',
#    'Published_At': '2023-10-01T09:00:17Z',
#    'Duration': 'PT40S',
#    'Thumbnail': 'https://i.ytimg.com/vi/IaJR6hZg76Q/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': '0i2A0gsuKKA',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '
Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery This Goan Restaurant Offers Dishes Cooked On Open Fire\n\nWelcome To Bawri which is located right in the heart of North Goa, Assagao\n\nThe ambiance has a touch of rustic and modern style.\n\nAnd also offers floor seating to unwind and relax\n\nIsn’t this a vibe?\n\nYou can also experience live tandoor cooking and grab yourself a drink at this majestic bar right here\n\nChef Amninder Sandhu prepared a delicious Bawri special meal for us\n\nWhich includes\nGutti Aloo\nWild mango curry with noolputtu rice noodles\nBawri butter chicken\nGoan prawn curry\nLast but not least Mutton Biryani\n\nOh my god look at that tender mutton piece!\n\nNo meal is complete without dessert and here we tried this\nDelicious chocolate pastry\nKesar Jalebi Rabdi\n\nSave this reel for your next visit to Goa!\n\nUntil then Cheers!\nAnd follow @curlytalesdigital For more\n\n#curlytales #foodandtravel #ctdiscovery #ytshorts #foodie #foodblogger #goanfood #kamiyajani',
#    'Video_Statistics': '3',
#    'Comment_Count': '3',
#    'View_Count': '13984',
#    'Like_Count': '585',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-30T06:45:02Z',
#    'Duration': 'PT57S',
#    'Thumbnail': 'https://i.ytimg.com/vi/aNoiYgOyyJU/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'Q0W6B7c77E8',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Welcoming You Onboard “Croma On Cruise” | Curly Tales #shorts',
#    'Video_Description': 'Welcoming you onboard “Croma on Cruise” to Experience One-of-a-kind Croma’s Experiential Pop-up On Sea!\nTag someone you’d like to experience this with & follow @curlytalesdigital \n@CromaRetail \n\n#curlytales #foodandtravel #croma #travel #cruise \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/\nCurly Tales App ►  https://curlytale.page.link/DwNd',
#    'Video_Statistics': '2',
#    'Comment_Count': '2',
#    'View_Count': '8299',
#    'Like_Count': '316',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-29T14:43:10Z',
#    'Duration': 'PT58S',
#    'Thumbnail': 'https://i.ytimg.com/vi/Q0W6B7c77E8/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': '5eLMLbEGH4Q',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Funny Moments With Shilpa Shetty | Curly Tales #shorts',
#    'Video_Description': 'Funny Moments With Shilpa Shetty😂😂\n\n\n#curlytales #shilpashetty #ytshorts #sukhi #kushakapila #funnymovement #shilpashettyvideo',
#    'Video_Statistics': '56',
#    'Comment_Count': '56',
#    'View_Count': '326161',
#    'Like_Count': '17242',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-29T13:30:02Z',
#    'Duration': 'PT24S',
#    'Thumbnail': 'https://i.ytimg.com/vi/5eLMLbEGH4Q/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'f6-hmi_JbeA',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Celebrating Krishna Janmashtami in Vrindavan | I Love My India | Curly Tales',
#    'Video_Description': 'Radhe radhe! Poore Braj me aap kahi bhi jao, Hi, Bye, Please, Thank you, Sorry inn sabhi shabdon ke liye log sirf ek term use karte hai- Radhe radhe!\n\nBrajdham, the region in UP with numerous stories of Radha Krishna has Mathura-Vrindavan as its center with the holy river Yamuna flowing right through it. Every location in this region is filled with stories of radha krishna, their Raasleela, krishna’s baal leela and so much folklore. Vrindavan lies at the center of all these tales.\n\nJanmashtami in Vrindavan was celebrated this year on the 7th of September and we were elated to be a part of it. We went around the town throughout the day, listening to stories from Brijwasi about their beloved krishna kanhaiya, the evening was spent boating and taking in the sunset on the ghats of the magical river yamuna followed by the ghat aarti. And the night was spent celebrating the birth of Krishna as we indulged in the festivities of Janmashtami at the Vrindavan Chandrodaya Mandir. \n\nWe got to experience all that and much more on our visit to the city of widows, Vrindavan. Have a look for yourself!\n\n#curlytales #janmashtami #virndavan #mandir #mathura #incredibleindia #india #festival #ilovemyindia \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/',
#    'Video_Statistics': '33',
#    'Comment_Count': '33',
#    'View_Count': '15548',
#    'Like_Count': '565',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-29T13:04:57Z',
#    'Duration': 'PT10M30S',
#    'Thumbnail': 'https://i.ytimg.com/vi/f6-hmi_JbeA/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': '8ccR_FTvxCY',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '31 Types Of Modak In Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery 31 types of Modak In Delhi\n\n📍Manohar Bikkaneri, Krishna Nagar\n\nTime: 9 am to 10 pm\n\nBolo Ganpati Bappa Moreya!\n\n\n#curlytales #ganeshchaturthi #travel #foodandtravel #sweettooth',
#    'Video_Statistics': '12',
#    'Comment_Count': '12',
#    'View_Count': '18093',
#    'Like_Count': '964',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-29T11:51:00Z',
#    'Duration': 'PT32S',
#    'Thumbnail': 'https://i.ytimg.com/vi/8ccR_FTvxCY/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'SWJJgFBPxPQ',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'This Place In Bandra Has To Be Your Next Date Spot | Curly Tales #shorts',
#    'Video_Description': 'This place in Bandra has to be your next date spot!\n\n📍Jhelum, Pali Naka, Bandra\n\nIt is a perfect restaurant for a brunch or dinner! The place looks like a European café but serves traditional north Indian food.\nWe tried the Murgh Raseela Seekh Kebab, Dahi KeKebab, Murgh Malai Kebab, Raseela Gosht Seekh Kebab, and they were lip-smacking for the main course we tried the Dal Peshawari, Goshst Nihari with Taftan that’s a type of flour bread.\nWe also had Meethi Yaadein, Malpua & omg this Phirni it is a must-try! The food is really delicious keeping it authentic to its original flavour.\n\nSo if you have a date or just want a family dinner you must try this restaurant!\n\nTag someone who would take it here \n follow @curlytalesdigital  for more!\n\n#curlytales #foodandtravel #ctdiscovery #ytshorts #foodie #foodblogger #date #bandra',
#    'Video_Statistics': '5',
#    'Comment_Count': '5',
#    'View_Count': '32312',
#    'Like_Count': '1250',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-28T16:45:01Z',
#    'Duration': 'PT59S',
#    'Thumbnail': 'https://i.ytimg.com/vi/SWJJgFBPxPQ/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'bGwJVF8VcTM',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Get 25 Types Of Parathas In Mumbai | Curly Tales #shorts',
#    'Video_Description': 'Get 25 Types Of Parathas In Mumbai\n\n📍 Khasiyat Paratha House , Vile Parle(W)\n\nCost : ₹320 start\n\nTopped with white Makhan\nServed with Chole, Black Lentils, Raita, and Pickle.\n\nTag A Friend You’d Like To Visit This Place\n\nFollow @curlytalesdigital  For More!\n\n#curlytales #foodandtravel #ytshorts #ctdiscovery #foodporn #foodblogger #foodie #foodphotography #delhi #delhidiaries #mumbai #mumbaifoodie #mumbaikar #explorepage #fyp',
#    'Video_Statistics': '6',
#    'Comment_Count': '6',
#    'View_Count': '21773',
#    'Like_Count': '910',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-28T14:45:03Z',
#    'Duration': 'PT33S',
#    'Thumbnail': 'https://i.ytimg.com/vi/bGwJVF8VcTM/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'v8NME2PL9gg',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Lotus Biscoff Paan In Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Lotus Biscoff Paan\nIn Delhi\n\n📍Yamu Panchayat CP Delhi\n\nTopped With Lotus Biscoff\n\nTime: 10am-12am\n\nTag Someone You’d Want To Try This With!',
#    'Video_Statistics': '4',
#    'Comment_Count': '4',
#    'View_Count': '19443',
#    'Like_Count': '598',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-28T14:15:02Z',
#    'Duration': 'PT33S',
#    'Thumbnail': 'https://i.ytimg.com/vi/v8NME2PL9gg/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'tA2kp-2rIos',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '59 Seconds With Kusha Kapila | Curly Tales #shorts',
#    'Video_Description': '#59Seconds With Kusha Kapila \n\n\n#curlytales #ytshorts #kushakapila #sundaybrunch #bollywood #interview #comedy #fungame',
#    'Video_Statistics': '107',
#    'Comment_Count': '107',
#    'View_Count': '386717',
#    'Like_Count': '22888',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-28T13:30:31Z',
#    'Duration': 'PT1M',
#    'Thumbnail': 'https://i.ytimg.com/vi/tA2kp-2rIos/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'YrZc9B2rdwg',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Authentic Goan Street Food In Pune | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Authentic Goan Street Food In Pune\nPocket & Pet Friendly .\n\n📍Margos Goan Street Food , Bhandarkar Road, Pune.\n\nThey serve authentic Goan poees made with Cafreal And Recheado masala.\nYou can find everything ₹100 on their menu\n\nTag Someone You’d Like To Visit This Restaurant With',
#    'Video_Statistics': '3',
#    'Comment_Count': '3',
#    'View_Count': '16064',
#    'Like_Count': '503',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-28T06:45:01Z',
#    'Duration': 'PT33S',
#    'Thumbnail': 'https://i.ytimg.com/vi/YrZc9B2rdwg/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'f2bDtLow090',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Water Spill Challenge With Kusha Kapila And Kamiya Jani | Curly Tales #shorts',
#    'Video_Description': 'When Things Got Wet and Wild with Kusha Kapila! 💦🤣 #WaterSpillChallenge\n\n#curlytales #kushakapila #fungame #bollywood #kamiyajani \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/',
#    'Video_Statistics': '7',
#    'Comment_Count': '7',
#    'View_Count': '74724',
#    'Like_Count': '2266',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-27T15:30:19Z',
#    'Duration': 'PT51S',
#    'Thumbnail': 'https://i.ytimg.com/vi/f2bDtLow090/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': '9jICSNsAB5k',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Ganpati Special With Sai Tamhankar | Tere Gully Mein Ep 57 | Curly Tales',
#    'Video_Description': "Ganpati Bappa Morya!! We’re back with another episode of Tere Gully Mein but this time instead of exploring an area, we’ve explored the essence of Ganeshotsav in the city. We were accompanied by a marathi mulgi from Sangli, the bold and beautiful Sai Tamhankar. We started our day with the darshan of GSB Seva Mandal’s Ganpati at Kings Circle.\n\nHere are the places we visited with Sai Tamhankar on this episode: \n📍GSB Seva Mandal’s Ganpati, Kings Circle\n📍Ladu Samrat\n📍Ketkar Caterers\n\nGaneshotsav in Mumbai is a total vibe. And to enjoy the festival in all its glory, we started the festivities at GSB Seva Mandal’s Navsala Pavnara Vishwacha Raja. It is India’s Richest Ganpati situated at King’s Circle. After a lovely darshan we proceeded to the annadan section where they serve a typical manglorean meal on a banana leaf as prasadam. We were served rice, dal, rasam, achaar, karela sabzi and payasam which made for a delicious meal.\n\nFrom there we headed out to have some Maharashtrian snacks at Ladu Samrat which is in the heart of Mumbai, Parel. Lalbaug- Parel undoubtedly is the best place in the world to enjoy the grand celebrations of Ganeshotsav. We ate batata wada, alu vadi, kothimbir vadi, thalipeeth and some kharvas as a sweet dish. The meal was complete with piyush in the end.\n\nGanesh Chaturthi is synonymous with ukdiche modaks. So that had to be our last stop. We visited a generations old place called Ketkar Caterers at Dadar TT who have been serving scrumptious modaks for years along with a lot of other items.\n\nSai tried her hand at making ukdiche modak and if you ask us, aced it in the first go! We spoke a lot about ganeshot

#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '5 Places On Earth With Weird Gravitational Pull | Curly Tales #shorts',
#    'Video_Description': "5 Places On Earth With Weird Gravitational Pull.\n\n#CTRecommends 5 Places On Earth With Weird Gravitational Pull\n1. Mystery Spot, Santa Cruz California\nExperience optical illusions and peculiar gravitational anomalies at this famous location\n\n2. St. Ignace mystery spot, Michigan\nEncounter bizarre phenomena that defy gravity's norms in Michigan's mysterious attraction\n\n3. Cosmos Mystery Area, Rapid City\nVisit a place where the laws of physics seem to twist and turn, leaving visitors bewildered\n\n4. Spook Hill, Florida\nWitness cars rolling uphill seemingly on their own in this enigmatic gravitational anomaly in Florida\n\n5. Magnetic Hill, Leh\nDefy gravity as your vehicle appears to move uphill without power on this intriguing road in Leh, India\n\n\n#curlytales #kamiyajani #foodandtravel #travel #ytshorts",
#    'Video_Statistics': '3',
#    'Comment_Count': '3',
#    'View_Count': '14880',
#    'Like_Count': '597',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-27T06:45:00Z',
#    'Duration': 'PT41S',
#    'Thumbnail': 'https://i.ytimg.com/vi/AudQBklkmzk/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'e6NTQQ6U5rc',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '70 Years Old Kanji VadaIn Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery 70 Years Old Kanji Vada\nIn Delhi\n\n📍Bhagirath Palace, Chandini Chowk\n\nCost - ₹60\n\nTiming- 11:30am to 6pm\n\nGuptaji Serves Best Dahi Bhalle Chaat In Chandini Chowk With Kanji Vada.\n\nTag A Dahi Bhalle Lover !\n\n#curlytales #foodandtravel #ytshorts #viral #foodie #foodblogger #delhi #newdelhi #chandnichowk',
#    'Video_Statistics': '2',
#    'Comment_Count': '2',
#    'View_Count': '24026',
#    'Like_Count': '860',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-26T13:44:50Z',
#    'Duration': 'PT31S',
#    'Thumbnail': 'https://i.ytimg.com/vi/e6NTQQ6U5rc/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'mWiYig-z62E',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Try These Rare & Unique Fish Dishes Now In Pune | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Try These Rare & Unique Fish Dishes\nNow In Pune\n\n📍Kunal Icon Shopping Complex, Pune.\n\nThey serve Mix seafood platter at affordable prices. We loved their Speciality Patrani Machi & Potli briyani\n\nTag a seafood lover\n\n#curlytales #foodandtravel #foodie #pune #foodblogger #vlogger #seafood \n\n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/',
#    'Video_Statistics': '12',
#    'Comment_Count': '12',
#    'View_Count': '23950',
#    'Like_Count': '885',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-26T13:42:51Z',
#    'Duration': 'PT38S',
#    'Thumbnail': 'https://i.ytimg.com/vi/mWiYig-z62E/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': '0D_NBlTfKDU',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Vande Bharat Themed Ganpati Pandal In Mumbai | Curly Tales #shorts',
#    'Video_Description': 'Vande Bharat Themed Ganpati Pandal In Mumbai.\n\n#curlytales #kamiyajani #ganeshchaturthi #festival #vandebharatexpress',
#    'Video_Statistics': '8',
#    'Comment_Count': '8',
#    'View_Count': '28677',
#    'Like_Count': '1156',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-26T09:34:44Z',
#    'Duration': 'PT38S',
#    'Thumbnail': 'https://i.ytimg.com/vi/0D_NBlTfKDU/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'S1YctSbkw7c',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '59 Seconds With Vicky Kaushal | Curly Tales #shorts',
#    'Video_Description': '59 Seconds With Vicky Kaushal.\n\n#vickykaushal #sundaybrunch #bollywood #59seconds #curlytales #kamiyajani #foodandtravel',
#    'Video_Statistics': '39',
#    'Comment_Count': '39',
#    'View_Count': '334678',
#    'Like_Count': '17904',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-26T09:32:09Z',
#    'Duration': 'PT1M',
#    'Thumbnail': 'https://i.ytimg.com/vi/S1YctSbkw7c/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'msbIRfwYya4',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '

#    'Favorite_Count': '0',
#    'Published_At': '2023-09-25T12:43:36Z',
#    'Duration': 'PT58S',
#    'Thumbnail': 'https://i.ytimg.com/vi/aZRPJxEQDgY/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'Smsk6WmDpTM',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '59 Seconds With Shilpa Shetty | Curly Tales #shorts',
#    'Video_Description': '59 Seconds With Shilpa Shetty.\n\n#shilpashetty #curlytales #59seconds #sundaybrunch #funny #foodandtravel #bollywood #entertainment',
#    'Video_Statistics': '510',
#    'Comment_Count': '510',
#    'View_Count': '5057010',
#    'Like_Count': '255357',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-25T12:13:10Z',
#    'Duration': 'PT1M',
#    'Thumbnail': 'https://i.ytimg.com/vi/Smsk6WmDpTM/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'NdmUekinsa0',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'This Shop In Bandra Let’s You Rent Designer Indian Outfits On A Budget | Curly Tales #shorts',
# ...
#    'Video_Name': 'Giant Chocolate Modak In Delhi | Curly Tales #shorts',
#    'Video_Description': 'Giant Chocolate Modak In Delhi\n\n📍Cocopots Kamla Nagar\n\nServed With Small Modals Inside It\n\nPrice :- 2200\n\nTimings :- 11am to 11pm\n\nTag Your Modak Buddy!\n\n#curlytales #foodandtravel #ctdiscovery #ytshorts #foodie #foodblogger #delhi #delhifood #delhifoodie #modak #ganeshchaturthi',
#    'Video_Statistics': '38',
#    'Comment_Count': '38',
#    'View_Count': '23580',
#    'Like_Count': '983',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-24T05:00:34Z',
#    'Duration': 'PT30S',
#    'Thumbnail': 'https://i.ytimg.com/vi/vpu8TTlq_hk/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'pBJ8DGQB1ag',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': "Delhi's Fastest Dosa Maker | Curly Tales #shorts",
#    'Video_Description': '#CTDiscovery Delhi’s Fastest Dosa Maker\n\n📍Janpath, Connaught Place\n\nServes Masala Dosa, Vada Idli, Onion Uttapam\n\nCost: Starting From ₹80\n\nTime: 9:30am-9pm\n\nTag Your Dosa Buddy!\n\n#curlytales #foodandtravel #foodie #ctdiscovery #foodblogger #ytshorts #delhi #delhifood #delhifoodie #streetfood #dosa #masaladosa',
#    'Video_Statistics': '12',
#    'Comment_Count': '12',
#    'View_Count': '47434',
#    'Like_Count': '1591',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-23T15:00:44Z',
#    'Duration': 'PT34S',
#    'Thumbnail': 'https://i.ytimg.com/vi/pBJ8DGQB1ag/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'qzpSdJgU1dg',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Chole Kulcha Chaat In Delhi | Curly Tales #shorts',
#    'Video_Description': 'Chole Kulcha Chaat In Delhi.\n\n#curlytales #streetfood #foodandtravel #delhi #cholebhaturae',
#    'Video_Statistics': '6',
#    'Comment_Count': '6',
#    'View_Count': '39276',
#    'Like_Count': '1292',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-23T10:30:27Z',
#    'Duration': 'PT27S',
#    'Thumbnail': 'https://i.ytimg.com/vi/qzpSdJgU1dg/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'rkCHCCYtHfA',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Graduate Selling Tea On The Streets Of Delhi | Curly Tales #shorts',
#    'Video_Description': '#CTDiscovery Graduate Selling Tea On The Streets Of Delhi\n\n📍JJ’s Thadi Mukherjee Nagar\n\nTopped With Rose Petals For Added Flavour\n\nCost: Starting From Rs15\n\nTime: 10am-12am\n\nTag Someone You’d Want To Try This With!\n\n#curlytales #foodandtravel #ctdiscovery #foodblogger #foodie #delhi #delhifood #delhifoodie #streetfood #chai #chailovers',
#    'Video_Statistics': '9',
#    'Comment_Count': '9',
#    'View_Count': '29694',
#    'Like_Count': '1181',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-23T08:07:31Z',
#    'Duration': 'PT27S',
#    'Thumbnail': 'https://i.ytimg.com/vi/rkCHCCYtHfA/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'ddGQEnu62gc',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': 'Pizza Served On Wheels In Lucknow | Curly Tales #shorts',
#    'Video_Description': 'Pizza Served On Wheels In Lucknow.\n\n#curlytales #foodandtravel #kamiyajani #travel #foodie #foodblogger #lucknow',
#    'Video_Statistics': '1',
#    'Comment_Count': '1',
#    'View_Count': '22675',
#    'Like_Count': '1051',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-23T06:45:02Z',
#    'Duration': 'PT33S',
#    'Thumbnail': 'https://i.ytimg.com/vi/ddGQEnu62gc/default.jpg',
#    'Caption_Status': 'false'},
#   {'Video_ID': 'Zq3A6wi7IK4',
#    'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#    'Video_Name': '59 Seconds With Randeep Hooda | Curly Tales #shorts',
#    'Video_Description': '59 Seconds With Randeep Hooda.\n\n\n#curlytales #randeephooda #teregullymein #sundaybrunch #bollywood #interview #foodandtravel #foodie #59seconds',
#    'Video_Statistics': '358',
#    'Comment_Count': '358',
#    'View_Count': '1605903',
#    'Like_Count': '96966',
#    'Favorite_Count': '0',
#    'Published_At': '2023-09-22T16:00:28Z',
#    'Duration': 'PT1M',
#    'Thumbnail': 'https://i.ytimg.com/vi/Zq3A6wi7IK4/default.jpg',
#    'Caption_Status': 'false'}],
#  'comment details': [{'Video_iD': 'FRR55XRcuHY',
#    'Comment_Id': 'UgyJbokQyKxkEhkwZ2F4AaABAg',
#    'Comment_Text': 'Raj loves having Raj Kachori in mask 🎭',
#    'Comment_Author': 'Anant Kashyap',
#    'Comment_PublishedAt': '2023-10-03T21:00:55Z'},
#   {'Video_iD': 'RvI_ObX0rLQ',
#    'Comment_Id': 'Ugzp6NTR7tkusCJArJ54AaABAg',
#    'Comment_Text': '❤Hum Duniya Ke Vishwa Guru Hain 😊Hum Duniya Me Sabse Jyada Tarakki Karke Sabko Peechhe Chhod Denge ❤',
#    'Comment_Author': 'Atul pandit',
#    'Comment_PublishedAt': '2023-10-04T01:30:56Z'},
#   {'Video_iD': 'wVol-v3WglQ',
#    'Comment_Id': 'Ugy64rDQ5OK9QS6RsCB4AaABAg',
#    'Comment_Text': '0',
#    'Comment_Author': 'doc pal',
#    'Comment_PublishedAt': '2023-10-03T20:51:26Z'},
#   {'Video_iD': 'gvDClSHLhCk',
#    'Comment_Id': 'UgxNJJDd36jGePTh5kB4AaABAg',
#    'Comment_Text': 'कल्याण ची वाट लावली आहे खाज दार आहे लाज वाटू द्या',
#    'Comment_Author': 'Umesh Deshmukh',
#    'Comment_PublishedAt': '2023-10-03T19:41:30Z'},
#   {'Video_iD': '8KikL1A8tYI',
#    'Comment_Id': 'Ugx9IGhxTVt9KIlj0fd4AaABAg',
#    'Comment_Text': 'I like shilpa she is very pretty.. but at times she makes extremely weird faces ! example: @<a href="https://www.youtube.com/watch?v=8KikL1A8tYI&amp;t=0m22s">0:22</a> 😒',
#    'Comment_Author': 'Fia S Chaudhry',
#    'Comment_PublishedAt': '2023-10-03T11:18:26Z'},
#   {'Video_iD': 'GBS2R4Iiado',
#    'Comment_Id': 'UgzfAsAQKpP-9DY8Jtx4AaABAg',
#    'Comment_Text': 'Where’s Kamya?',
#    'Comment_Author': 'Himanshu Bhatt',
#    'Comment_PublishedAt': '2023-10-03T08:55:57Z'},
#   {'Video_iD': '-hRYBY1F2Jc',
#    'Comment_Id': 'Ugy6d67A56sJGxxBQNZ4AaABAg',
#    'Comment_Text': 'The way u introduced and mentioned abt ur show.. hhhaa<br>As if we don’t know ‘Kamiya’..😝😉',
#    'Comment_Author': 'Bhar Santa',
#    'Comment_PublishedAt': '2023-10-03T05:15:41Z'},
#   {'Video_iD': 'V5N0inwvFoo',
#    'Comment_Id': 'UgzK892wkehOkyvKWVZ4AaABAg',
#    'Comment_Text': 'It is looking very dirty and unhygienic',
#    'Comment_Author': 'Drakula R',
#    'Comment_PublishedAt': '2023-10-02T18:02:25Z'},
#   {'Video_iD': 'oKN0rdp3Ak0',
#    'Comment_Id': 'Ugx9zP6TVISpMPIWGwd4AaABAg',
#    'Comment_Text': 'India ka roll/Frankie is Afghanistan&#39;s burger?? 🤔',
#    'Comment_Author': 'Saurabh Sinha',
#    'Comment_PublishedAt': '2023-10-02T01:05:44Z'},
#   {'Video_iD': 'OQfK8sa6FQw',
#    'Comment_Id': 'UgwB0Iub6Vv1PAb8tz54AaABAg',
#    'Comment_Text': 'Good curiy channel',
#    'Comment_Author': 'Mohammedsubhan Khan',
#    'Comment_PublishedAt': '2023-10-02T12:07:46Z'},
#   {'Video_iD': 'vfeFeCq14n8',
#    'Comment_Id': 'UgyE_Tx2K-YtVVIoev94AaABAg',
#    'Comment_Text': 'What the hell 😂😂😂😂',
#    'Comment_Author': 'shubham dev',
#    'Comment_PublishedAt': '2023-10-01T13:43:06Z'},
#   {'Video_iD': 'IaJR6hZg76Q',
#    'Comment_Id': 'Ugz8_zp9mqG6LiBkQ-V4AaABAg',
#    'Comment_Text': '2 log😂 agar bhookh lagi ho toh akela hi kha lunga',
#    'Comment_Author': 'mayank lahari',
#    'Comment_PublishedAt': '2023-10-02T13:50:53Z'},
#   {'Video_iD': '0i2A0gsuKKA',
#    'Comment_Id': 'UgyFDPtMiSWK6OdoPzF4AaABAg',
#    'Comment_Text': 'One of the best video of Curly Tales',
#    'Comment_Author': 'Darimika Laloo',
#    'Comment_PublishedAt': '2023-10-03T20:50:51Z'},
#   {'Video_iD': 'Cx2T0zYEJw4',
#    'Comment_Id': 'UgyaRD_TbS-pTGc-Ol94AaABAg',
#    'Comment_Text': 'Coi- sans 😂 such clowns.',
#    'Comment_Author': 'Asmita S',
#    'Comment_PublishedAt': '2023-09-30T16:11:18Z'},
#   {'Video_iD': '9gZXrWybYfA',
#    'Comment_Id': 'UgzFSAdvLT4ypgvscP94AaABAg',
#    'Comment_Text': 'They use wall paint brush for applying ghee',
#    'Comment_Author': 'shivu cutiepie',
#    'Comment_PublishedAt': '2023-10-01T06:32:20Z'},
#   {'Video_iD': '5DQeQi8LXDc',
#    'Comment_Id': 'Ugw8i54vRg9COcaJd894AaABAg',
#    'Comment_Text': 'I would love to come on this train with my mom and dad and grandparents 😁😊',
#    'Comment_Author': 'Anurag Vaidya',
#    'Comment_PublishedAt': '2023-10-01T18:37:53Z'},
#   {'Video_iD': 'fF5eo4xK3_g',
#    'Comment_Id': 'UgwwcQq30_GP1YoFRzZ4AaABAg',
#    'Comment_Text': '❤❤❤🎉🎉🎉',
#    'Comment_Author': 'Mohammedsubhan Khan',
#    'Comment_PublishedAt': '2023-10-01T17:31:23Z'},
#   {'Video_iD': 'aNoiYgOyyJU',
#    'Comment_Id': 'Ugw35TpRjbcoz5oD9Ip4AaABAg',
#    'Comment_Text': 'Kya lagta hai - khaa payenge ye log ?',
#    'Comment_Author': 'uturn rturn',
#    'Comment_PublishedAt': '2023-09-30T11:42:36Z'},
#   {'Video_iD': 'Q0W6B7c77E8',
#    'Comment_Id': 'UgxgpvDSxOrPFkrRLtx4AaABAg',
#    'Comment_Text': 'Address?',
#    'Comment_Author': 'Ansh Shah',
#    'Comment_PublishedAt': '2023-09-29T14:47:16Z'},
#   {'Video_iD': '5eLMLbEGH4Q',
#    'Comment_Id': 'Ugyey_ASr4qRq2nkN9N4AaABAg',
#    'Comment_Text': 'Shilpa too good',
#    'Comment_Author': 'Davina Iyasawmy',
#    'Comment_PublishedAt': '2023-10-04T05:09:34Z'},
#   {'Video_iD': 'f6-hmi_JbeA',
#    'Comment_Id': 'UgwpSH1ugs8pcx_XIe14AaABAg',
#    'Comment_Text': '☝️🕉️☝️🇮🇳☝️ Hare Krishna. Jai Hind.',
#    'Comment_Author': 'Sean Bellfort',
#    'Comment_PublishedAt': '2023-09-30T23:26:32Z'},
#   {'Video_iD': '8ccR_FTvxCY',
#    'Comment_Id': 'UgyRgN4_33XQZj5ockF4AaABAg',
#    'Comment_Text': 'Ganpati bappa mouryaa❤❤😊',
#    'Comment_Author': 'Archi Gupta',
#    'Comment_PublishedAt': '2023-10-02T07:52:48Z'},
#   {'Video_iD': 'SWJJgFBPxPQ',
#    'Comment_Id': 'UgyJvzWPdqF4YhIKqs54AaABAg',
#    'Comment_Text': 'Jhelum is a name of river in Kashmir',
#    'Comment_Author': 'Mayur M',
#    'Comment_PublishedAt': '2023-09-30T09:53:33Z'},
#   {'Video_iD': 'bGwJVF8VcTM',
#    'Comment_Id': 'UgyORmCmIgJYr90kuK94AaABAg',
#    'Comment_Text': '60₹ is the ideal price for Paratha',
#    'Comment_Author': 'Mayur M',
#    'Comment_PublishedAt': '2023-09-30T09:54:16Z'},
#   {'Video_iD': 'v8NME2PL9gg',
#    'Comment_Id': 'Ugwq8JCUHna3JF3s4JZ4AaABAg',
#    'Comment_Text': 'Kya bakwas hai ye 😂',
#    'Comment_Author': 'Amar Pandey',
#    'Comment_PublishedAt': '2023-10-02T04:17:20Z'},
#   {'Video_iD': 'tA2kp-2rIos',
#    'Comment_Id': 'UgyoLDrL2VphZm-9mlx4AaABAg',
#    'Comment_Text': 'Who is she.. actually 😅',
#    'Comment_Author': 'AJKR',
#    'Comment_PublishedAt': '2023-10-03T15:53:50Z'},
#   {'Video_iD': 'YrZc9B2rdwg',
#    'Comment_Id': 'UgzTHo_USx5-g1HioP14AaABAg',
#    'Comment_Text': 'I&#39;m from goa .. yeh toh goa mein bhi nahi milta 💀',
#    'Comment_Author': 'the blank channel',
#    'Comment_PublishedAt': '2023-09-28T13:07:50Z'},
#   {'Video_iD': 'f2bDtLow090',
#    'Comment_Id': 'Ugy9AGdS6paj5oGr-0Z4AaABAg',
#    'Comment_Text': 'Kusha ko kya hua 😂<br>Abhi zameen pe layenge bolly waale rukja 😂',
#    'Comment_Author': 'mohd Saif ali',
#    'Comment_PublishedAt': '2023-09-29T16:40:41Z'},
#   {'Video_iD': '9jICSNsAB5k',
#    'Comment_Id': 'UgwTf6wxVAq9LTaDqsx4AaABAg',
#    'Comment_Text': 'Baju wala thaili bhul k gaya shayad',
#    'Comment_Author': 'suraj',
#    'Comment_PublishedAt': '2023-10-03T09:47:43Z'},
#   {'Video_iD': 'wPVu5lK-8rY',
#    'Comment_Id': 'Ugwy_S8BYAS5r8eViax4AaABAg',
#    'Comment_Text': 'Jai shree Ganesh 🙏❤️❤️❤❤🙏📚📚📚👑👑👑👑👑👑👑👑👑👑🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏📚👑👑📚📚👑👑👑👑👑📚📚📚',
#    'Comment_Author': 'Anupma Srivastava',
#    'Comment_PublishedAt': '2023-10-02T06:35:36Z'},
#   {'Video_iD': 'Itv10IA7QFY',
#    'Comment_Id': 'UgwzA1yfaVgiiviKvYp4AaABAg',
#    'Comment_Text': 'That SRK pose was unnecessary',
#    'Comment_Author': 'Mayur M',
#    'Comment_PublishedAt': '2023-09-28T13:34:46Z'},
#   {'Video_iD': 'AudQBklkmzk',
#    'Comment_Id': 'Ugxp4cka_AHBAbpYWpJ4AaABAg',
#    'Comment_Text': 'There is a temple and place in Gujarat  called kala dungar which also has this  weird kind of gravitational force',
#    'Comment_Author': 'Divyashree Pai Bhat',
#    'Comment_PublishedAt': '2023-09-28T10:42:59Z'},
#   {'Video_iD': 'e6NTQQ6U5rc',
#    'Comment_Id': 'UgwrLN-zpDDk-Zz2L9h4AaABAg',
#    'Comment_Text': '6pm*',
#    'Comment_Author': 'Lubhna Kaul',
#    'Comment_PublishedAt': '2023-09-26T14:19:09Z'},
#   {'Video_iD': 'mWiYig-z62E',
#    'Comment_Id': 'UgwuFu0KrmmZ7uJMuvx4AaABAg',
#    'Comment_Text': 'Bengali fish h wo, we steam fish with mustard paste and green chillies in banana leaf. Kuch bhi mtlb. Paturi h wo, patrani nhi h',
#    'Comment_Author': 'Anindita Mitra',
#    'Comment_PublishedAt': '2023-09-28T17:15:09Z'},
#   {'Video_iD': '0D_NBlTfKDU',
#    'Comment_Id': 'Ugw8Uugg-mpSEdg9Qhh4AaABAg',
#    'Comment_Text': 'Nice..',
#    'Comment_Author': 'Bhar Santa',
#    'Comment_PublishedAt': '2023-10-01T01:38:23Z'},
#   {'Video_iD': 'S1YctSbkw7c',
#    'Comment_Id': 'UgwoPC1RvWFfIK4g7mh4AaABAg',
#    'Comment_Text': 'Vicky kaushal is real personality 😊no fake attitude no drama',
#    'Comment_Author': 'Megha Mittal',
#    'Comment_PublishedAt': '2023-10-03T05:48:40Z'},
#   {'Video_iD': 'msbIRfwYya4',
#    'Comment_Id': 'UgzWs_azvaXH15IkWtt4AaABAg',
#    'Comment_Text': '5.Stock palace',
#    'Comment_Author': 'Sanjay Sharma',
#    'Comment_PublishedAt': '2023-09-25T16:03:52Z'},
#   {'Video_iD': 'rBxk49emoPk',
#    'Comment_Id': 'UgztrCcZAV4Nxi1eYPx4AaABAg',
#    'Comment_Text': 'बेवकूफियों की भी हद होती है, यहां पूजा करने पर भगवान में ध्यान कम पैसों में ध्यान ज्यादा लगा रहेगा😅😅😅',
#    'Comment_Author': 'Multi vlogs',
#    'Comment_PublishedAt': '2023-10-01T03:54:34Z'},
#   {'Video_iD': 'aZRPJxEQDgY',
#    'Comment_Id': 'UgzZVf_6squ24QBULhN4AaABAg',
#    'Comment_Text': 'Lovely 🌹😍❤❤❤❤❤',
#    'Comment_Author': 'Preet Khilwani',
#    'Comment_PublishedAt': '2023-09-25T19:42:09Z'},
#   {'Video_iD': 'Smsk6WmDpTM',
#    'Comment_Id': 'UgycbRmfVjVi4CmzSHN4AaABAg',
#    'Comment_Text': 'My mother  name is also shilpa',
#    'Comment_Author': 'Santosh Jain',
#    'Comment_PublishedAt': '2023-10-04T05:50:00Z'},
#   {'Video_iD': 'NdmUekinsa0',
#    'Comment_Id': 'UgyfMkadYAoKoCAFWIB4AaABAg',
#    'Comment_Text': 'Good option rather than buying.<br>But rent prices itself seem to b high..😮😢',
#    'Comment_Author': 'Bhar Santa',
#    'Comment_PublishedAt': '2023-09-25T14:45:44Z'},
#   {'Video_iD': 'RNvaB6DzDxs',
#    'Comment_Id': 'UgxLn_RGL7ui3j-T2Op4AaABAg',
#    'Comment_Text': 'Koi nh dekh ke he khush ho lete hai 6.5 lakh me to 2 saal ki emi pay kar luga home loan ki',
#    'Comment_Author': 'Ss Nt',
#    'Comment_PublishedAt': '2023-09-25T01:05:03Z'},
#   {'Video_iD': 'JT2WODYQMu8',
#    'Comment_Id': 'UgyqJ_ODvTrVkGOpQFh4AaABAg',
#    'Comment_Text': 'Dhosa not dosa 😂😂😂😂',
#    'Comment_Author': 'bhagwan darshan',
#    'Comment_PublishedAt': '2023-09-24T18:49:38Z'},
#   {'Video_iD': 'HL1_hHUxOmg',
#    'Comment_Id': 'UgxgEkdi6TDhKgJdGEd4AaABAg',
#    'Comment_Text': 'Most entertained episode from curly tales 👏👌',
#    'Comment_Author': 'TheRandomThings',
#    'Comment_PublishedAt': '2023-10-04T02:20:55Z'},
#   {'Video_iD': 'vpu8TTlq_hk',
#    'Comment_Id': 'UgxDRBmdIzZ2U7LSek14AaABAg',
#    'Comment_Text': 'Jai shree Ganesh ❤',
#    'Comment_Author': 'Anupma Srivastava',
#    'Comment_PublishedAt': '2023-10-03T09:58:06Z'},
#   {'Video_iD': 'pBJ8DGQB1ag',
#    'Comment_Id': 'UgwlOjaPq-vitsi6OlR4AaABAg',
#    'Comment_Text': 'Plz voice accent change kro irritating',
#    'Comment_Author': 'Miracles Happen 😊',
#    'Comment_PublishedAt': '2023-09-26T13:32:17Z'},
#   {'Video_iD': 'qzpSdJgU1dg',
#    'Comment_Id': 'Ugzy0MB8xKzh7TNqjVx4AaABAg',
#    'Comment_Text': 'Yrr bohat bure lagte hain ye. kulche to apne unique style main hi achhe lagte hain. Chhole ke sath chahe jo experiment kar lo 😅',
#    'Comment_Author': 'The_unsatisfied_soul',
#    'Comment_PublishedAt': '2023-09-30T15:18:48Z'},
#   {'Video_iD': 'rkCHCCYtHfA',
#    'Comment_Id': 'UgzbkIXSQX3ORA8SdFp4AaABAg',
#    'Comment_Text': 'Sugar should be put in the end not in the beginning 😅',
#    'Comment_Author': 'Anushka Khare',
#    'Comment_PublishedAt': '2023-09-23T15:27:25Z'},
#   {'Video_iD': 'ddGQEnu62gc',
#    'Comment_Id': 'UgziZaXM2FRffVooIGp4AaABAg',
#    'Comment_Text': '❤ U R A Best Great Lucknowite In The Town 😊Agar Lucknow Ka Bachcha Bachcha Jaag Gaya To Lucknow Dubai London New York Ko Peeche Chhod Dega ❤ Thanks Curly Tales ❤😊',
#    'Comment_Author': 'Atul pandit',
#    'Comment_PublishedAt': '2023-09-23T07:02:49Z'},
#   {'Video_iD': 'Zq3A6wi7IK4',
#    'Comment_Id': 'UgyqC9t6vJQNOjho1gp4AaABAg',
#    'Comment_Text': 'Hey Randeep :-Bla bla bla bla <br>Randeep -No',
#    'Comment_Author': 'RANDOM_INSANE',
#    'Comment_PublishedAt': '2023-10-04T04:19:45Z'}]}

# %%
# Data Migration (converting unstructured data to structured data)
# store data to SQLite
st.header(':orange[Data Migrate zone]')
st.write ('''(Note:- This zone specific channel data **Migrate to :blue[SQLite] database from  :green[MongoDB] database** depending on your selection,
                if unavailable your option first collect data.)''')

# %%
# MongoDB connection and store the collected data
# Connect to mongodb atlas
client = MongoClient("mongodb+srv://indhujagadeeswaran:sumathi09@cluster0.ki2kcii.mongodb.net/?retryWrites=true&w=majority")

# %%
# Create mongodb database and collection
db = client['database_youtube']
collection = db['collection_channel']

# %%
#Insert channel data
collection.insert_one(d)

# %%
d = st.selectbox('**Select Channel name**', options = d, key= d)
st.write('''Migrate to SQLite database from MongoDB database to click below **:blue['Migrate to SQLite']**.''')
Migrate = st.button('**Migrate to SQLite**')

# %%
# Define Session state to Migrate to MySQL button
if 'migrate_sql' not in st.session_state:
        st.session_state_migrate_sql = False
if Migrate or st.session_state_migrate_sql:
        st.session_state_migrate_sql = True

# %%
# Retrieve the document with the specified name
result=d['channel details']

# %%
result
# Out:
# {'Channel_name': 'Curly Tales ',
#  'Channel_ID': 'UCDnq05Q89oYq-Tz5boL73Tw',
#  'Subscribers': '2570000',
#  'Views': '998914452',
#  'Description': "Welcome to Curly Tales - India's No. 1 food & travel channel, founded by Kamiya Jani. We'll take you on a journey through some of the most offbeat locations & the quirkiest, craziest food discoveries. So hop on, and enjoy the ride as we bring to you 7 exclusive shows, every day of the week:\n\nSunday Brunch with Kamiya Jani: A fun tete a tete with India's biggest celebrities \nCT Discovery: Unique food & places across India, you KNOW you can't miss out on\nTere Gully Mein: A walk down memory lane with popular influencers, as they take us through their favourite gullies & food memories\nThe Solo Female Traveller: Neha Nambiar's solo journey through India's wilderness. Sometimes luxury, but mostly budget trips\nCT Exclusives: The best deals on food & travel, that you won't get anywhere else!\nI Love My India: Our country has so much to offer, & we bring you Bharat's beauty in all its glory\nWanderluxe: Have you ever wondered what outrageous, OTT luxury lives like? Well, we're here to show you\n",
#  'Total_Videos': '3424',
#  'Playlist_id': 'UUDnq05Q89oYq-Tz5boL73Tw'}

# %%
# Data Migrate to SQLite
# Connect to the SQLite database
con = sqlite3.connect("youtubeSQLITE.db")
cur = con.cursor()

# %%
#Create Channel Table
cur.execute("CREATE TABLE Channel(Channel_name TEXT,Channel_ID TEXT,Subscribers INTEGER,Views INTEGER,Description TEXT,Total_Videos INTEGER,Playlist_id TEXT)")

# %%
cur.execute(f"""INSERT INTO Channel VALUES {tuple(result.values())}""")
con.commit()

# %%
# Retrieve the document with the specified name
result1=d['video details'][0]

# %%
result1
# Out:
# {'Video_ID': 'FRR55XRcuHY',
#  'Channel_Id': 'UCDnq05Q89oYq-Tz5boL73Tw',
#  'Video_Name': 'Does this kachori come in a mask? Guess We’ll Never Know | Curly Tales #shorts',
#  'Video_Description': 'Does this kachori come in a mask? Guess we’ll never know!!😂🤪\n\n#rajkachori #shilpashetty #kushakapila #curlytales #funnymovement #ytshorts #bollywood #viral #travel \n\nOther Social Accounts:\nFollow us on Facebook ►https://www.facebook.com/curlytales/\nFollow us on Instagram ►https://www.instagram.com/curly.tales/\nCurly Tales Website ► https://curlytales.com/\nCurly Tales App ►  https://curlytale.page.link/DwNd',
#  'Video_Statistics': '5',
#  'Comment_Count': '5',
#  'View_Count': '12233',
#  'Like_Count': '812',
#  'Favorite_Count': '0',
#  'Published_At': '2023-10-03T15:45:00Z',
#  'Duration': 'PT53S',
#  'Thumbnail': 'https://i.ytimg.com/vi/FRR55XRcuHY/default.jpg',
#  'Caption_Status': 'false'}

# %%
#Create Video Table
cur.execute("CREATE TABLE Video(Video_ID TEXT,Channel_ID TEXT,Video_Name TEXT,Video_Description TEXT,Video_Statistics INTEGER,Comment_Count INTEGER,View_Count INTEGER,Like_Count INTEGER,Favorite_Count INTEGER,Published_At INTEGER,Duration TEXT,Thumbnail TEXT,Caption_Status TEXT)")

# %%
cur.execute(f"""INSERT INTO Video VALUES {tuple(result1.values())}""")
con.commit()

# %%
# Retrieve the document with the specified name
result2=d['comment details'][0]

# %%
result2
# Out:
# {'Video_iD': 'FRR55XRcuHY',
#  'Comment_Id': 'UgyJbokQyKxkEhkwZ2F4AaABAg',
#  'Comment_Text': 'Raj loves having Raj Kachori in mask 🎭',
#  'Comment_Author': 'Anant Kashyap',
#  'Comment_PublishedAt': '2023-10-03T21:00:55Z'}

# %%
#Create Comment Table
cur.execute("CREATE TABLE Comment(Video_Id TEXT,Comment_Id TEXT,Comment_Text TEXT,Comment_Author TEXT,Comment_PublishedAt INTEGER)")

# %%
cur.execute(f"""INSERT INTO Comment VALUES {tuple(result2.values())}""")
con.commit()

# %%
# Questions for Analysing Data
st.subheader(':violet[Channels Analysis]')

question_tosql = st.selectbox('**Select your Question**',
        ('1. What are the names of all the videos and their corresponding channels?',
        '2. Which channels have the most number of videos, and how many videos do they have?',
        '3. What are the top 10 most viewed videos and their respective channels?',
        '4. How many comments were made on each video, and what are their corresponding video names?',
        '5. Which videos have the highest number of likes, and what are their corresponding channel names?',
        '6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?',
        '7. What is the total number of views for each channel, and what are their corresponding channel names?',
        '8. What are the names of all the channels that have published videos in the year 2023?',
        '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?',
        '10. Which videos have the highest number of comments, and what are their corresponding channel names?'), key = 'collection_question')

# %%
con_for_question = sqlite3.connect("youtubeSQLITE.db")
cur = con_for_question.cursor()

# %%
# Q1
if question_tosql == '1. What are the names of all the videos and their corresponding channels?':
    cur.execute("select channel.Channel_name,video.Video_Name from video inner join channel on video.Channel_ID=channel.Channel_ID;")
    result_1 = cur.fetchall()
    df1 = pd.DataFrame(result_1, columns=['Channel Name', 'Video Name']).reset_index(drop=True)
    df1.index += 1
    st.dataframe(df1)

# %%
# Q2
elif question_tosql == '2. Which channels have the most number of videos, and how many videos do they have?':

    col1,col2 = st.columns(2)
    with col1:
        cur.execute("SELECT Channel_name, Total_Videos FROM channel ORDER BY Total_Videos DESC;")
        result_2 = cur.fetchall()
        df2 = pd.DataFrame(result_2,columns=['Channel Name','Total Videos']).reset_index(drop=True)
        df2.index += 1
        st.dataframe(df2)

    with col2:
        fig_vc = px.bar(df2, y='Total Videos', x='Channel Name', text_auto='.2s', title="Most number of videos", )
        fig_vc.update_traces(textfont_size=16,marker_color='#E6064A')
        fig_vc.update_layout(title_font_color='#1308C2 ',title_font=dict(size=25))
        st.plotly_chart(fig_vc,use_container_width=True)

# %%
# Q3
elif question_tosql == '3. What are the top 10 most viewed videos and their respective channels?':

    col1,col2 = st.columns(2)
    with col1:
        cursor.execute("SELECT channel.Channel_Name, video.Video_Name, video.View_Count FROM channel JOIN video ON channel.Channel_Id = video.Channel_Id  ORDER BY video.View_Count DESC LIMIT 10;")
        result_3 = cursor.fetchall()
        df3 = pd.DataFrame(result_3,columns=['Channel Name', 'Video Name', 'View count']).reset_index(drop=True)
        df3.index += 1
        st.dataframe(df3)

    with col2:
        fig_topvc = px.bar(df3, y='View count', x='Channel Name', text_auto='.2s', title="Top 10 most viewed videos")
        fig_topvc.update_traces(textfont_size=16,marker_color='#E6064A')
        fig_topvc.update_layout(title_font_color='#1308C2 ',title_font=dict(size=25))
        st.plotly_chart(fig_topvc,use_container_width=True)

# %%
# Q4
elif question_tosql == '4. How many comments were made on each video, and what are their corresponding video names?':
    cur.execute("SELECT video.Video_Name, video.Comment_Count FROM video JOIN comment ON video.Video_Id = comment.Video_Id;")
    result_4 = cur.fetchall()
    df4 = pd.DataFrame(result_4,columns=['Video Name', 'Comment count']).reset_index(drop=True)
    df4.index += 1
    st.dataframe(df4)

# %%
# Q5
elif question_tosql == '5. Which videos have the highest number of likes, and what are their corresponding channel names?':
    cur.execute("SELECT channel.Channel_Name, video.Video_Name, video.Like_Count FROM channel JOIN video ON channel.Channel_Id = video.Channel_Id ORDER BY video.Like_Count DESC;")
    result_5= cur.fetchall()
    df5 = pd.DataFrame(result_5,columns=['Channel Name', 'Video Name', 'Like count']).reset_index(drop=True)
    df5.index += 1
    st.dataframe(df5)

# %%
# Q6
elif question_tosql == '6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?':
    st.write('**Note:- In November 2021, YouTube removed the public dislike count from all of its videos.**')
    cur.execute("SELECT channel.Channel_Name, video.Video_Name, video.Like_Count  FROM channel JOIN video ON channel.Channel_ID = video.Channel_ID ORDER BY video.Like_Count DESC;")
    result_6= cur.fetchall()
    df6 = pd.DataFrame(result_6,columns=['Channel Name', 'Video Name', 'Like count']).reset_index(drop=True)
    df6.index += 1
    st.dataframe(df6)

# %%
# Q7
elif question_tosql == '7. What is the total number of views for each channel, and what are their corresponding channel names?':

    col1, col2 = st.columns(2)
    with col1:
        cur.execute("SELECT channel.Channel_name, channel.Views FROM channel ORDER BY Views DESC;")
        result_7= cur.fetchall()
        df7 = pd.DataFrame(result_7,columns=['Channel Name', 'Total number of views']).reset_index(drop=True)
        df7.index += 1
        st.dataframe(df7)

    with col2:
        fig_topview = px.bar(df7, y='Total number of views', x='Channel Name', text_auto='.2s', title="Total number of views", )
        fig_topview.update_traces(textfont_size=16,marker_color='#E6064A')
        fig_topview.update_layout(title_font_color='#1308C2 ',title_font=dict(size=25))
        st.plotly_chart(fig_topview,use_container_width=True)

# %%
# Q8
elif question_tosql == '8. What are the names of all the channels that have published videos in the year 2023?':
    cur.execute("SELECT channel.Channel_name,video.Video_Name,video.Published_At FROM channel JOIN video ON channel.Channel_ID= video.Channel_ID WHERE strftime('%Y',Published_At) ='2023';")
    result_8= cur.fetchall()
    df8 = pd.DataFrame(result_8,columns=['Channel Name','Video Name', 'Year 2023 only']).reset_index(drop=True)
    df8.index += 1
    st.dataframe(df8)

# %%
# Q9
elif question_tosql == '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?':
    cur.execute("select channel.Channel_name,video.Duration from channel JOIN Video ON channel.Channel_ID=video.Channel_ID GROUP BY Channel_name ORDER BY Duration DESC;")
    result_9= cur.fetchall()
    df9 = pd.DataFrame(result_9,columns=['Channel Name','Duration']).reset_index(drop=True)
    df9.index += 1
    st.dataframe(df9)

# %%
# Q10
elif question_tosql == '10. Which videos have the highest number of comments, and what are their corresponding channel names?':
    cur.execute("SELECT channel.Channel_name, video.Video_Name, video.Comment_Count FROM channel JOIN video ON channel.Channel_ID= video.Channel_ID  ORDER BY VIDEO.Comment_Count DESC;")
    result_10= cur.fetchall()
    df10 = pd.DataFrame(result_10,columns=['Channel Name','Video Name', 'Number of comments']).reset_index(drop=True)
    df10.index += 1
    st.dataframe(df10)

# %%
# SQLite DB connection close
con_for_question.close()
